# %% [markdown]
# This notebook converts the breed list into the expected format in Breedle.

# %%
breeds = [
    { "key": "affenpinscher", "label": "Affenpinscher" },
    { "key": "afghan_hound", "label": "Afghan Hound" },
    { "key": "airedale_terrier", "label": "Airedale Terrier" },
    { "key": "akita", "label": "Akita", "variants": [
      { "key": "japanese", "label": "Japanese" }
    ]},
    { "key": "alaskan_malamute", "label": "Alaskan Malamute" },
    { "key": "american_hairless_terrier", "label": "American Hairless Terrier" },
    { "key": "american_staffordshire_terrier", "label": "American Staffordshire Terrier" },
    { "key": "anatolian_shepherd_dog", "label": "Anatolian Shepherd Dog" },
    { "key": "australian_cattle_dog", "label": "Australian Cattle Dog" },
    { "key": "australian_kelpie", "label": "Australian Kelpie" },
    { "key": "australian_shepherd", "label": "Australian Shepherd" },
    { "key": "australian_silky_terrier", "label": "Australian Silky Terrier" },
    { "key": "australian_stumpy_tail_cattle_dog", "label": "Australian Stumpy Tail Cattle Dog" },
    { "key": "australian_terrier", "label": "Australian Terrier" },
    { "key": "azawakh", "label": "Azawakh" },
    { "key": "basenji", "label": "Basenji" },
    { "key": "basset_fauve_de_bretagne", "label": "Basset Fauve de Bretagne" },
    { "key": "basset_hound", "label": "Basset Hound" },
    { "key": "beagle", "label": "Beagle" },
    { "key": "bearded_collie", "label": "Bearded Collie" },
    { "key": "beauceron", "label": "Beauceron" },
    { "key": "bedlington_terrier", "label": "Bedlington Terrier" },
    { "key": "belgian_shepherd_dog", "label": "Belgian Shepherd Dog", "variants": [
      {"key": "groenendael", "label": "Groenendael"},
      {"key": "laekenois", "label": "Laekenois"},
      {"key": "malinois", "label": "Malinois"},
      {"key": "tervueren", "label": "Tervueren"}
    ]},
    { "key": "bergamasco_shepherd_dog", "label": "Bergamasco Shepherd Dog" },
    { "key": "bernese_mountain_dog", "label": "Bernese Mountain Dog" },
    { "key": "bichon_frise", "label": "Bichon Frise" },
    { "key": "black_and_tan_coonhound", "label": "Black and Tan Coonhound" },
    { "key": "bloodhound", "label": "Bloodhound" },
    { "key": "bluetick_coonhound", "label": "Bluetick Coonhound" },
    { "key": "bolognese", "label": "Bolognese" },
    { "key": "border_collie", "label": "Border Collie" },
    { "key": "border_terrier", "label": "Border Terrier" },
    { "key": "borzoi", "label": "Borzoi" },
    { "key": "boston_terrier", "label": "Boston Terrier" },
    { "key": "bouvier_des_flandres", "label": "Bouvier des Flandres" },
    { "key": "boxer", "label": "Boxer" },
    { "key": "bracco_italiano", "label": "Bracco Italiano" },
    { "key": "briard", "label": "Briard" },
    { "key": "british_bulldog", "label": "British Bulldog" },
    { "key": "brittany", "label": "Brittany" },
    { "key": "bull_terrier", "label": "Bull Terrier", "variants": [
      { "key": "miniature", "label": "Miniature" }
    ]},
    { "key": "bullmastiff", "label": "Bullmastiff" },
    { "key": "cairn_terrier", "label": "Cairn Terrier" },
    { "key": "canaan_dog", "label": "Canaan Dog" },
    { "key": "canadian_eskimo_dog", "label": "Canadian Eskimo Dog" },
    { "key": "cane_corso", "label": "Cane Corso" },
    { "key": "caucasian_shepherd_dog", "label": "Caucasian Shepherd Dog" },
    { "key": "cavalier_king_charles_spaniel", "label": "Cavalier King Charles Spaniel" },
    { "key": "central_asian_shepherd_dog", "label": "Central Asian Shepherd Dog" },
    { "key": "cesky_terrier", "label": "Cesky Terrier" },
    { "key": "chesapeake_bay_retriever", "label": "Chesapeake Bay Retriever" },
    { "key": "chihuahua", "label": "Chihuahua", "variants": [
      { "key": "long_coat", "label": "Long Coat"},
      { "key": "smooth_coat", "label": "Smooth Coat" }
    ]},
    { "key": "chinese_crested_dog", "label": "Chinese Crested Dog" },
    { "key": "chow_chow", "label": "Chow Chow" },
    { "key": "cirneco_dell_etna", "label": "Cirneco Dell'Etna" },
    { "key": "clumber_spaniel", "label": "Clumber Spaniel" },
    { "key": "cocker_spaniel", "label": "Cocker Spaniel", "variants": [
      { "key": "american", "label": "American" }
    ]},
    { "key": "collie", "label": "Collie", "variants": [
      { "key": "rough", "label": "Rough"},
      { "key": "smooth", "label": "Smooth" }
    ]},
    { "key": "coton_de_tulear", "label": "Coton De Tulear" },
    { "key": "curly_coated_retriever", "label": "Curly Coated Retriever" },
    { "key": "dachshund", "label": "Dachshund", "variants": [
      { "key": "long_haired", "label": "Long Haired"},
      { "key": "miniature_long_haired", "label": "Miniature Long Haired" },
      { "key": "miniature_smooth_haired", "label": "Miniature Smooth Haired" },
      { "key": "miniature_wire_haired", "label": "Miniature Wire Haired" },
      { "key": "smooth_haired", "label": "Smooth Haired" },
      { "key": "wire_haired", "label": "Wire Haired" }
    ]},
    { "key": "dachshund_kaninchen", "label": "Dachshund Kaninchen", "variants": [
      { "key": "long_haired", "label": "Long Haired" },
      { "key": "smooth_haired", "label": "Smooth Haired" },
      { "key": "wire_haired", "label": "Wire Haired" }
    ]},
    { "key": "dalmatian", "label": "Dalmatian" },
    { "key": "dandie_dinmont_terrier", "label": "Dandie Dinmont Terrier" },
    { "key": "deerhound", "label": "Deerhound" },
    { "key": "dobermann", "label": "Dobermann" },
    { "key": "dogue_de_bordeaux", "label": "Dogue de Bordeaux" },
    { "key": "dutch_shepherd_dog", "label": "Dutch Shepherd Dog" },
    { "key": "english_setter", "label": "English Setter" },
    { "key": "english_springer_spaniel", "label": "English Springer Spaniel" },
    { "key": "english_toy_terrier", "label": "English Toy Terrier", "variants": [
      { "key": "black_and_tan", "label": "Black and Tan"}
    ]},
    { "key": "estrela_mountain_dog", "label": "Estrela Mountain Dog" },
    { "key": "eurasier", "label": "Eurasier" },
    { "key": "field_spaniel", "label": "Field Spaniel" },
    { "key": "finnish_lapphund", "label": "Finnish Lapphund" },
    { "key": "finnish_spitz", "label": "Finnish Spitz" },
    { "key": "flat_coated_retriever", "label": "Flat Coated Retriever" },
    { "key": "fox_terrier", "label": "Fox Terrier", "variants": [
      { "key": "smooth", "label": "Smooth"},
      { "key": "wire", "label": "Wire" }
    ]},
    { "key": "foxhound", "label": "Foxhound" },
    { "key": "french_bulldog", "label": "French Bulldog" },
    { "key": "german_hunting_terrier", "label": "German Hunting Terrier" },
    { "key": "german_pinscher", "label": "German Pinscher" },
    { "key": "german_shepherd_dog", "label": "German Shepherd Dog", "variants": [
      { "key": "stock_coat", "label": "Stock Coat" },
      { "key": "long_stock_coat", "label": "Long Stock Coat" }
    ]},
    { "key": "german_shorthaired_pointer", "label": "German Shorthaired Pointer" },
    { "key": "german_spitz", "label": "German Spitz", "variants": [
      { "key": "klein", "label": "Klein"},
      { "key": "mittel", "label": "Mittel" }
    ]},
    { "key": "german_wirehaired_pointer", "label": "German Wirehaired Pointer" },
    { "key": "glen_of_imaal_terrier", "label": "Glen of Imaal Terrier" },
    { "key": "golden_retriever", "label": "Golden Retriever" },
    { "key": "gordon_setter", "label": "Gordon Setter" },
    { "key": "grand_basset_griffon_vendeen", "label": "Grand Basset Griffon Vendeen" },
    { "key": "great_dane", "label": "Great Dane" },
    { "key": "greyhound", "label": "Greyhound" },
    { "key": "griffon_bruxellois", "label": "Griffon Bruxellois" },
    { "key": "hamiltonstovare", "label": "Hamiltonstovare" },
    { "key": "harrier", "label": "Harrier" },
    { "key": "havanese", "label": "Havanese" },
    { "key": "hungarian_vizsla", "label": "Hungarian Vizsla" },
    { "key": "hungarian_wirehaired_vizsla", "label": "Hungarian Wirehaired Vizsla" },
    { "key": "ibizan_hound", "label": "Ibizan Hound" },
    { "key": "icelandic_sheepdog", "label": "Icelandic Sheepdog" },
    { "key": "irish_red_and_white_setter", "label": "Irish Red and White Setter" },
    { "key": "irish_setter", "label": "Irish Setter" },
    { "key": "irish_terrier", "label": "Irish Terrier" },
    { "key": "irish_water_spaniel", "label": "Irish Water Spaniel" },
    { "key": "irish_wolfhound", "label": "Irish Wolfhound" },
    { "key": "italian_greyhound", "label": "Italian Greyhound" },
    { "key": "italian_spinone", "label": "Italian Spinone" },
    { "key": "jack_russell_terrier", "label": "Jack Russell Terrier" },
    { "key": "japanese_chin", "label": "Japanese Chin" },
    { "key": "japanese_spitz", "label": "Japanese Spitz" },
    { "key": "kangal_shepherd_dog", "label": "Kangal Shepherd Dog" },
    { "key": "karelian_bear_dog", "label": "Karelian Bear Dog" },
    { "key": "keeshond", "label": "Keeshond" },
    { "key": "kerry_blue_terrier", "label": "Kerry Blue Terrier" },
    { "key": "king_charles_spaniel", "label": "King Charles Spaniel" },
    { "key": "komondor", "label": "Komondor" },
    { "key": "kuvasz", "label": "Kuvasz" },
    { "key": "labrador_retriever", "label": "Labrador Retriever" },
    { "key": "lagotto_romagnolo", "label": "Lagotto Romagnolo" },
    { "key": "lakeland_terrier", "label": "Lakeland Terrier" },
    { "key": "landseer", "label": "Landseer", "variants": [
      { "key": "european_continental_type", "label": "European Continental Type"}
    ]},
    { "key": "large_munsterlander", "label": "Large Munsterlander" },
    { "key": "leonberger", "label": "Leonberger" },
    { "key": "lhasa_apso", "label": "Lhasa Apso" },
    { "key": "lowchen", "label": "Lowchen" },
    { "key": "maltese", "label": "Maltese" },
    { "key": "manchester_terrier", "label": "Manchester Terrier" },
    { "key": "maremma_sheepdog", "label": "Maremma Sheepdog" },
    { "key": "mastiff", "label": "Mastiff" },
    { "key": "miniature_pinscher", "label": "Miniature Pinscher" },
    { "key": "neapolitan_mastiff", "label": "Neapolitan Mastiff" },
    { "key": "newfoundland", "label": "Newfoundland" },
    { "key": "norfolk_terrier", "label": "Norfolk Terrier" },
    { "key": "norwegian_buhund", "label": "Norwegian Buhund" },
    { "key": "norwegian_elkhound", "label": "Norwegian Elkhound" },
    { "key": "norwich_terrier", "label": "Norwich Terrier" },
    { "key": "nova_scotia_duck_tolling_retriever", "label": "Nova Scotia Duck Tolling Retriever" },
    { "key": "old_english_sheepdog", "label": "Old English Sheepdog" },
    { "key": "otterhound", "label": "Otterhound" },
    { "key": "papillon", "label": "Papillon", "variants": [
      { "key": "phalene", "label": "Phalène"}
    ]},
    { "key": "parson_russell_terrier", "label": "Parson Russell Terrier" },
    { "key": "pekingese", "label": "Pekingese" },
    { "key": "peruvian_hairless_dog", "label": "Peruvian Hairless Dog", "variants": [
      { "key": "large", "label": "Large" },
      { "key": "medium", "label": "Medium" },
      { "key": "small", "label": "Small" }
    ]},
    { "key": "petit_basset_griffon_vendeen", "label": "Petit Basset Griffon Vendeen" },
    { "key": "pharaoh_hound", "label": "Pharaoh Hound" },
    { "key": "pointer", "label": "Pointer" },
    { "key": "polish_lowland_sheepdog", "label": "Polish Lowland Sheepdog" },
    { "key": "pomeranian", "label": "Pomeranian" },
    { "key": "poodle", "label": "Poodle", "variants": [
      { "key": "miniature", "label": "Miniature" },
      { "key": "standard", "label": "Standard" },
      { "key": "toy", "label": "Toy" }
    ]},
    { "key": "portuguese_podengo", "label": "Portuguese Podengo", "variants": [
      { "key": "large_smooth_haired", "label": "Large Smooth Haired" },
      { "key": "large_wire_haired", "label": "Large Wire Haired" },
      { "key": "medium_smooth_haired", "label": "Medium Smooth Haired" },
      { "key": "medium_wire_haired", "label": "Medium Wire Haired" },
      { "key": "small_smooth_haired", "label": "Small Smooth Haired" },
      { "key": "small_wire_haired", "label": "Small Wire Haired" }
    ]},
    { "key": "portuguese_water_dog", "label": "Portuguese Water Dog" },
    { "key": "pug", "label": "Pug" },
    { "key": "puli", "label": "Puli" },
    { "key": "pumi", "label": "Pumi" },
    { "key": "pyrenean_mastiff", "label": "Pyrenean Mastiff" },
    { "key": "pyrenean_mountain_dog", "label": "Pyrenean Mountain Dog" },
    { "key": "pyrenean_sheepdog_longhaired", "label": "Pyrenean Sheepdog Longhaired" },
    { "key": "rhodesian_ridgeback", "label": "Rhodesian Ridgeback" },
    { "key": "rottweiler", "label": "Rottweiler" },
    { "key": "russian_black_terrier", "label": "Russian Black Terrier" },
    { "key": "russian_toy", "label": "Russian Toy", "variants": [
      { "key": "long_haired", "label": "Long Haired" },
      { "key": "smooth_haired", "label": "Smooth Haired" }
    ]},
    { "key": "saluki", "label": "Saluki" },
    { "key": "samoyed", "label": "Samoyed" },
    { "key": "schipperke", "label": "Schipperke" },
    { "key": "schnauzer", "label": "Schnauzer", "variants": [
      { "key": "giant", "label": "Giant" },
      { "key": "miniature", "label": "Miniature" }
    ]},
    { "key": "scottish_terrier", "label": "Scottish Terrier" },
    { "key": "sealyham_terrier", "label": "Sealyham Terrier" },
    { "key": "shar_pei", "label": "Shar Pei" },
    { "key": "shetland_sheepdog", "label": "Shetland Sheepdog" },
    { "key": "shiba_inu", "label": "Shiba Inu" },
    { "key": "shih_tzu", "label": "Shih Tzu" },
    { "key": "siberian_husky", "label": "Siberian Husky" },
    { "key": "skye_terrier", "label": "Skye Terrier" },
    { "key": "sloughi", "label": "Sloughi" },
    { "key": "soft_coated_wheaten_terrier", "label": "Soft Coated Wheaten Terrier" },
    { "key": "spanish_mastiff", "label": "Spanish Mastiff" },
    { "key": "spanish_water_dog", "label": "Spanish Water Dog" },
    { "key": "st_bernard", "label": "St Bernard" },
    { "key": "staffordshire_bull_terrier", "label": "Staffordshire Bull Terrier" },
    { "key": "sussex_spaniel", "label": "Sussex Spaniel" },
    { "key": "swedish_lapphund", "label": "Swedish Lapphund" },
    { "key": "swedish_vallhund", "label": "Swedish Vallhund" },
    { "key": "tatra_shepherd_dog", "label": "Tatra Shepherd Dog" },
    { "key": "tenterfield_terrier", "label": "Tenterfield Terrier" },
    { "key": "tibetan_mastiff", "label": "Tibetan Mastiff" },
    { "key": "tibetan_spaniel", "label": "Tibetan Spaniel" },
    { "key": "tibetan_terrier", "label": "Tibetan Terrier" },
    { "key": "tornjak", "label": "Tornjak" },
    { "key": "weimaraner", "label": "Weimaraner", "variants": [
      { "key": "long-haired", "label": "Long-haired" }
    ]},
    { "key": "welsh_corgi", "label": "Welsh Corgi", "variants": [
      { "key": "cardigan", "label": "Cardigan" },
      { "key": "pembroke", "label": "Pembroke" }
    ]},
    { "key": "welsh_springer_spaniel", "label": "Welsh Springer Spaniel" },
    { "key": "welsh_terrier", "label": "Welsh Terrier" },
    { "key": "west_highland_white_terrier", "label": "West Highland White Terrier" },
    { "key": "whippet", "label": "Whippet" },
    { "key": "white_swiss_shepherd_dog", "label": "White Swiss Shepherd Dog" },
    { "key": "wirehaired_slovakian_pointer", "label": "Wirehaired Slovakian Pointer" },
    { "key": "xoloitzcuintle", "label": "Xoloitzcuintle", "variants": [
      { "key": "intermediate", "label": "Intermediate" },
      { "key": "miniature", "label": "Miniature" },
      { "key": "standard", "label": "Standard" }
    ]},
    { "key": "yakutian_laika", "label": "Yakutian Laika" },
    { "key": "yorkshire_terrier", "label": "Yorkshire Terrier" }
]

# %%
for b in breeds:
    b["code"] = b["key"]
    b["name"] = b["label"]
    b["latitude"] = 0.0
    b["longitude"] = 0.0
    del b["key"]
    del b["label"]

# %%
breeds
# Out:
# [{'code': 'affenpinscher',
#   'name': 'Affenpinscher',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'afghan_hound',
#   'name': 'Afghan Hound',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'airedale_terrier',
#   'name': 'Airedale Terrier',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'variants': [{'key': 'japanese', 'label': 'Japanese'}],
#   'code': 'akita',
#   'name': 'Akita',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'alaskan_malamute',
#   'name': 'Alaskan Malamute',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'american_hairless_terrier',
#   'name': 'American Hairless Terrier',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'american_staffordshire_terrier',
#   'name': 'American Staffordshire Terrier',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'anatolian_shepherd_dog',
#   'name': 'Anatolian Shepherd Dog',
#   'latitude': 0.0,
#   'longitude': 0.0},
#  {'code': 'australian_cattle_dog',
# ...

# %%
print(json.dumps(breeds, indent=2, sort_keys=True))
# Out:
# [
#   {
#     "code": "affenpinscher",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "Affenpinscher"
#   },
#   {
#     "code": "afghan_hound",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "Afghan Hound"
#   },
#   {
#     "code": "airedale_terrier",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "Airedale Terrier"
#   },
#   {
#     "code": "akita",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "Akita",
#     "variants": [
#       {
#         "key": "japanese",
#         "label": "Japanese"
#       }
#     ]
#   },
#   {
#     "code": "alaskan_malamute",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "Alaskan Malamute"
#   },
#   {
#     "code": "american_hairless_terrier",
#     "latitude": 0.0,
#     "longitude": 0.0,
#     "name": "American Hairless Terrier"
#   },
#   {
#     "code": "american_staffordshire_terrier",
#     "latitude": 0.0,
#     "longitude": 0.0,
# ...

# %%
codes = []
for b in breeds:
    codes.append(b["code"])

# %%
codes
# Out:
# ['affenpinscher',
#  'afghan_hound',
#  'airedale_terrier',
#  'akita',
#  'alaskan_malamute',
#  'american_hairless_terrier',
#  'american_staffordshire_terrier',
#  'anatolian_shepherd_dog',
#  'australian_cattle_dog',
#  'australian_kelpie',
#  'australian_shepherd',
#  'australian_silky_terrier',
#  'australian_stumpy_tail_cattle_dog',
#  'australian_terrier',
#  'azawakh',
#  'basenji',
#  'basset_fauve_de_bretagne',
#  'basset_hound',
#  'beagle',
#  'bearded_collie',
#  'beauceron',
#  'bedlington_terrier',
#  'belgian_shepherd_dog',
#  'bergamasco_shepherd_dog',
#  'bernese_mountain_dog',
#  'bichon_frise',
#  'black_and_tan_coonhound',
#  'bloodhound',
#  'bluetick_coonhound',
#  'bolognese',
#  'border_collie',
#  'border_terrier',
#  'borzoi',
#  'boston_terrier',
#  'bouvier_des_flandres',
#  'boxer',
#  'bracco_italiano',
#  'briard',
#  'british_bulldog',
#  'brittany',
#  'bull_terrier',
#  'bullmastiff',
#  'cairn_terrier',
#  'canaan_dog',
#  'canadian_eskimo_dog',
# ...
